# %%
# !python --version
# Out:
# Python 3.10.9

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('forestfires.csv')

# %%
data.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
data.shape
# Out:
# (517, 13)

# %%
y = data.temp
x = data.drop(columns = ['month','day','temp'])

# %%
y.head()
# Out:
# 0     8.2
# 1    18.0
# 2    14.6
# 3     8.3
# 4    11.4
# Name: temp, dtype: float64

# %%
x.head()
# Out:
#    X  Y  FFMC   DMC     DC  ISI  RH  wind  rain  area
# 0  7  5  86.2  26.2   94.3  5.1  51   6.7   0.0   0.0
# 1  7  4  90.6  35.4  669.1  6.7  33   0.9   0.0   0.0
# 2  7  4  90.6  43.7  686.9  6.7  33   1.3   0.0   0.0
# 3  8  6  91.7  33.3   77.5  9.0  97   4.0   0.2   0.0
# 4  8  6  89.3  51.3  102.2  9.6  99   1.8   0.0   0.0

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25)

# %%
x_train
# Out:
#      X  Y  FFMC    DMC     DC   ISI  RH  wind  rain   area
# 89   6  5  91.7   35.8   80.8   7.8  25   4.9   0.0   0.00
# 155  7  4  94.8  108.3  647.1  17.0  47   1.3   0.0   1.56
# 283  3  4  86.9    6.6   18.7   3.2  35   3.1   0.0   1.10
# 375  6  5  91.2   94.3  744.4   8.4  57   4.9   0.0  39.35
# 355  4  4  92.1   99.0  745.3   9.6  35   4.9   0.0  13.06
# ..  .. ..   ...    ...    ...   ...  ..   ...   ...    ...
# 206  2  2  93.5  139.4  594.2  20.3  31   7.2   0.0  15.45
# 296  6  4  90.4   89.5  290.8   6.4  46   1.8   0.0   0.90
# 511  8  6  81.6   56.7  665.6   1.9  35   2.7   0.0   0.00
# 220  8  6  90.2   99.6  631.2   6.3  59   3.1   0.0  32.07
# 422  8  6  88.9  263.1  795.9   5.2  27   3.6   0.0   6.30
#
# [387 rows x 10 columns]

# %%
x_test
# Out:
#      X  Y  FFMC    DMC     DC   ISI  RH  wind  rain   area
# 499  7  5  96.1  181.1  671.2  14.3  63   4.9   6.4  10.82
# 158  2  4  92.1  111.2  654.1   9.6  35   4.0   0.0   1.64
# 463  6  5  75.1    4.4   16.2   1.9  82   6.3   0.0   5.39
# 286  7  6  91.2  183.1  437.7  12.5  90   7.6   0.2   0.00
# 66   2  2  92.4  117.9  668.0  12.2  37   4.5   0.0   0.00
# ..  .. ..   ...    ...    ...   ...  ..   ...   ...    ...
# 160  7  4  90.1   39.7   86.6   6.2  29   3.1   0.0   1.75
# 277  3  4  85.4   25.4  349.7   2.6  21   8.5   0.0  10.73
# 453  4  5  89.4  266.2  803.3   5.6  54   3.1   0.0   0.00
# 80   1  2  91.4  142.4  601.4  10.6  39   6.3   0.0   0.00
# 339  2  4  91.6  108.4  764.0   6.2  41   1.8   0.0   1.47
#
# [130 rows x 10 columns]

# %%
y_train
# Out:
# 89     17.4
# 155    16.4
# 283     8.8
# 375    15.4
# 355    20.8
#        ...
# 206    22.9
# 296    14.3
# 511    27.8
# 220    16.2
# 422    29.3
# Name: temp, Length: 387, dtype: float64

# %%
y_test
# Out:
# 499    27.3
# 158    20.5
# 463     4.6
# 286    12.6
# 66     23.0
#        ...
# 160    16.1
# 277     4.6
# 453    17.4
# 80     19.5
# 339    20.4
# Name: temp, Length: 130, dtype: float64

# %%
model = LinearRegression().fit(x_train,y_train)

# %%
predictions = model.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,predictions)

plt.xlabel = 'Actual Values'
plt.ylabel = 'Predicted Values'
plt.show()
